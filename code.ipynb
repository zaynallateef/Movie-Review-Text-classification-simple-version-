# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv('../projects/moviereviews.tsv',sep='\t')

# %%
df.head()
# Out:
#   label                                             review
# 0   neg  how do films like mouse hunt get into theatres...
# 1   neg  some talented actresses are blessed with a dem...
# 2   pos  this has been an extraordinary year for austra...
# 3   pos  according to hollywood movies made in last few...
# 4   neg  my first press screening of 1998 and already i...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   2000 non-null   str
#  1   review  1965 non-null   str
# dtypes: str(2)
# memory usage: 31.4 KB

# %%
# we have missing values

# %%
df.dropna(inplace=True)

# %%
blanks=[] 
for i,ib,rv in df.itertuples():
    if rv.isspace():
        blanks.append(i)

# %%
df.drop(blanks,inplace=True)

# %%
len(df)
# Out:
# 1938

# %%
from sklearn.model_selection import train_test_split

# %%
x=df['review']
y=df['label']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn.pipeline import Pipeline 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# %%
svm_classifier=Pipeline([('tfidf',TfidfVectorizer()),
                          ('classifier',LinearSVC())])

# %%
svm_classifier.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('classifier', LinearSVC())])

# %%
pred=svm_classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[259  49]
#  [ 49 283]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.84      0.84      0.84       308
#          pos       0.85      0.85      0.85       332
#
#     accuracy                           0.85       640
#    macro avg       0.85      0.85      0.85       640
# weighted avg       0.85      0.85      0.85       640

# %%
print(f"The accuracy of the SVM model is: {accuracy_score(y_test, pred):.2f}")
# Out:
# The accuracy of the SVM model is: 0.85

# %%
# now other models
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
#logisticRegression
lr_classifier = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', LogisticRegression(max_iter=1000))
])

# %%
#NaiveBayes
nb_classifier = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', MultinomialNB())
])

# %%
#randomForest
rf_classifier = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', RandomForestClassifier(random_state=42))
])

# %%
#decisionTree
dt_classifier = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', DecisionTreeClassifier(random_state=42))
])

# %%
models = {
    "SVM": svm_classifier,
    "Logistic Regression": lr_classifier,
    "Naive Bayes": nb_classifier,
    "Random Forest": rf_classifier,
    "Decision Tree": dt_classifier
}

# %%
results = {}

for name, model in models.items():
    model.fit(x_train, y_train)

    predictions = model.predict(x_test)

    accuracy = accuracy_score(y_test, predictions)

    results[name] = accuracy

    print(f"{name}: {accuracy:.4f}")
# Out:
# SVM: 0.8469
# Logistic Regression: 0.8234
# Naive Bayes: 0.7641
# Random Forest: 0.7734
# Decision Tree: 0.6156

# %%
for name, model in models.items():
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)

    print("=" * 50)
    print(name)
    print(classification_report(y_test, predictions))
# Out:
# ==================================================
# SVM
#               precision    recall  f1-score   support
#
#          neg       0.84      0.84      0.84       308
#          pos       0.85      0.85      0.85       332
#
#     accuracy                           0.85       640
#    macro avg       0.85      0.85      0.85       640
# weighted avg       0.85      0.85      0.85       640
#
# ==================================================
# Logistic Regression
#               precision    recall  f1-score   support
#
#          neg       0.81      0.83      0.82       308
#          pos       0.84      0.81      0.83       332
#
#     accuracy                           0.82       640
#    macro avg       0.82      0.82      0.82       640
# weighted avg       0.82      0.82      0.82       640
#
# ==================================================
# Naive Bayes
#               precision    recall  f1-score   support
#
#          neg       0.69      0.93      0.79       308
#          pos       0.91      0.61      0.73       332
#
#     accuracy                           0.76       640
#    macro avg       0.80      0.77      0.76       640
# weighted avg       0.80      0.76      0.76       640
#
# ==================================================
# Random Forest
#               precision    recall  f1-score   support
#
#          neg       0.72      0.86      0.79       308
#          pos       0.84      0.69      0.76       332
#
#     accuracy                           0.77       640
#    macro avg       0.78      0.78      0.77       640
# weighted avg       0.78      0.77      0.77       640
#
# ==================================================
# Decision Tree
#               precision    recall  f1-score   support
#
#          neg       0.60      0.60      0.60       308
#          pos       0.63      0.63      0.63       332
#
#     accuracy                           0.62       640
#    macro avg       0.62      0.61      0.61       640
# weighted avg       0.62      0.62      0.62       640
